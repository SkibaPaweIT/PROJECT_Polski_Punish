# %%
R.version.string
# Out:
# [1] "R version 4.1.1 (2021-08-10)"

# %%
install.packages("e1071")

# %%
#Zad1
napoje <- read.csv(file = 'napoje_po_reklamie.csv' , sep=";")
head(napoje)

#Mean
sapply(napoje, mean, na.rm = T)
#Max
sapply(napoje, max, na.rm = T)
#Sum
sapply(napoje, sum, na.rm = T)
#Median
sapply(napoje, median, na.rm = T)
# Out:
#   mies pepsi  fanta żywiec okocim regionalne cola   lech
# 1 1    119110 41386 186272 64398  55561      215468 68673
# 2 2    107424 45669 178564 61847  48793      233941 68483
# 3 3    105748 47373 183368 53390  63907      229677 63300
# 4 4    115377 39395 184326 60062  58531      234246 61943
# 5 5    103003 42477 182190 63736  51395      219392 64189
# 6 6    102809 47224 183115 52596  55149      219600 63343
#       mies      pepsi      fanta     żywiec     okocim regionalne       cola
#       6.50  109203.83   42626.50  184355.33   60540.92   57229.17  226457.67
#       lech
#   62979.50
#       mies      pepsi      fanta     żywiec     okocim regionalne       cola
#         12     119110      51504     191763      67979      64720     235802
#       lech
#      68841
#       mies      pepsi      fanta     żywiec     okocim regionalne       cola
#         78    1310446     511518    2212264     726491     686750    2717492
#       lech
#     755754
# ...

# %%
#Zad2
mean( napoje[['pepsi']])
max( napoje[['pepsi']])
sum( napoje[['pepsi']])
median(napoje[['pepsi']])

mean( napoje[['fanta']])
max( napoje[['fanta']])
sum( napoje[['fanta']])
median(napoje[['fant']])
# Out:
# [1] 109203.8
# [1] 119110
# [1] 1310446
# [1] 107600.5
# [1] 42626.5
# [1] 51504
# [1] 511518
# NULL

# %%
#Zad3 
wzrost <- read.csv(file = 'Wzrost.csv' , sep=',' , header=FALSE)
wzrost2 <- t(wzrost)
summary(wzrost2)
# Out:
#        V1
#  Min.   :151.0
#  1st Qu.:160.2
#  Median :167.5
#  Mean   :174.2
#  3rd Qu.:187.5
#  Max.   :199.0
